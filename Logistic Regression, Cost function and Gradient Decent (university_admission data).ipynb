# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import math

# %%
adm=pd.read_csv(r'C:\Users\rohan\Downloads\university_admission.txt',delimiter=',',names=['Marks1','Marks2','Admission'])

# %%
adm.head()
# Out:
#       Marks1     Marks2  Admission
# 0  34.623660  78.024693          0
# 1  30.286711  43.894998          0
# 2  35.847409  72.902198          0
# 3  60.182599  86.308552          1
# 4  79.032736  75.344376          1

# %%
sns.scatterplot(adm.Marks1,adm.Marks2,hue=adm.Admission,marker="+")

# %%
X1=adm['Marks1']
X2=adm['Marks2']
Y=adm['Admission']
M=len(Y)

# %%
def hypfunction(theta0,theta1,theta2,i):
    Htheta=theta0+theta1*X1[i]+theta2*X2[i]
    sg=(1/(1+(math.exp(-Htheta))))
    return sg

# %%
def costFunction(theta0,theta1,theta2):
    Cost=0
    for i in range(M):
        cost=(-1/M)*((Y[i])*(math.log2(hypfunction(theta0,theta1,theta2,i)))+(1-Y[i])*(math.log2(1-hypfunction(theta0,theta1,theta2,i))))
        Cost=Cost+cost
    return Cost

# %%
theta0,theta1,theta2,alpha=0,0,0,0.00001
a=1
index=[]
costArray=[]
while(a<1000):
    J=0
    K=0
    L=0
    for i in range(M):
        j=alpha*(1/M)*((hypfunction(theta0,theta1,theta2,i)-Y[i]))
        J=J+j
        k=alpha*(1/M)*((hypfunction(theta0,theta1,theta2,i)-Y[i])*X1[i])
        K=K+k
        l=alpha*(1/M)*((hypfunction(theta0,theta1,theta2,i)-Y[i])*X2[i])
        L=L+l
    theta_0=theta0-J
    theta_1=theta1-K
    theta_2=theta2-L
    if(costFunction(theta0,theta1,theta2)<=costFunction(theta_0,theta_1,theta_2)):
        break
    else:
        theta0=theta_0
        theta1=theta_1
        theta2=theta_2
        index.append(a)
        a=a+1
        costArray.append(costFunction(theta0,theta1,theta2))

# %%
print(costArray)
# Out:
# [0.9961332673872646, 0.9924392233325383, 0.9889101190406366, 0.9855385348106529, 0.9823173691418245, 0.979239827799341, 0.9762994129000372, 0.9734899120700111, 0.970805387719008, 0.9682401664698027, 0.9657888287748884, 0.9634461987473558, 0.9612073342280686, 0.9590675171068811, 0.957022243911848, 0.9550672166769391, 0.953198334095831, 0.9514116829666633, 0.9497035299304325, 0.948070313503668, 0.9465086364043531, 0.9450152581686124, 0.9435870880544336, 0.9422211782276851, 0.9409147172248182, 0.9396650236859623, 0.9384695403515484, 0.9373258283151756, 0.9362315615250903, 0.9351845215264163, 0.9341825924361313, 0.9332237561426732, 0.9323060877220513, 0.9314277510623635, 0.9305869946886725, 0.9297821477803057, 0.9290116163727918, 0.9282738797367774, 0.9275674869264672, 0.926891053490316, 0.9262432583369162, 0.925622840749229, 0.9250285975405366, 0.9244593803457211, 0.9239140930416984, 0.9233916892910704, 0.9228911702032812, 0.9224115821077942, 0.9219520144340231, 0.9215115976929789, 0.9210895015557914, 0.9206849330244933, 0.9202971346906393, 0.9199253830775396, 0.9195689870620724, 0.9192272863722314, 0.9188996501567279, 0.918585475623155, 0.9182841867413721, 0.9179952330089323, 0.9177180882755209, 0.9174522496235349, 0.9171972363020392, 0.9169525887115174, 0.916717867436894, 0.9164926523265111, 0.9162765416147752, 0.9160691510863568, 0.9158701132799093, 0.9156790767293695, 0.9154957052410184, 0.9153196772045382, 0.9151506849364273, 0.9149884340541882, 0.9148326428797913, 0.9146830418709967, 0.9145393730791775, 0.9144013896323653, 0.9142688552422953, 0.9141415437342925, 0.9140192385988927, 0.9139017325641644, 0.9137888271877183, 0.9136803324674742, 0.9135760664702861, 0.9134758549775571, 0.9133795311470545, 0.9132869351901369, 0.9131979140636647, 0.913112321175908, 0.9130300161057683, 0.912950864334705, 0.912874736990756, 0.912801510604089, 0.9127310668735341, 0.9126632924435959, 0.9125980786914385, 0.9125353215233942, 0.9124749211805416, 0.9124167820529376, 0.9123608125020911, 0.9123069246913191, 0.9122550344235961, 0.9122050609865656, 0.9121569270043838, 0.9121105582960791, 0.9120658837401289, 0.9120228351449692, 0.9119813471251723, 0.9119413569830248, 0.9119028045952738, 0.9118656323047883, 0.9118297848169367, 0.9117952091004486, 0.9117618542925715, 0.911729671608315, 0.9116986142536226, 0.9116686373422658, 0.9116396978163263, 0.9116117543700702, 0.9115847673771045, 0.9115586988206299, 0.9115335122266834, 0.911509172600224, 0.9114856463639353, 0.911462901299631, 0.9114409064921491, 0.9114196322756201, 0.9113990501820074, 0.9113791328918256, 0.9113598541869339, 0.9113411889053197, 0.9113231128977809, 0.9113056029864371, 0.9112886369249658, 0.9112721933605175, 0.9112562517972194, 0.9112407925612023, 0.9112257967670865, 0.911211246285868, 0.9111971237141395, 0.911183412344586, 0.9111700961377142, 0.911157159694744, 0.9111445882316342, 0.91113236755417, 0.9111204840340885, 0.9111089245861899, 0.9110976766463841, 0.9110867281506531, 0.911076067514865, 0.911065683615431, 0.9110555657707471, 0.9110457037234003, 0.911036087623103, 0.9110267080103268, 0.9110175558006026, 0.9110086222694661, 0.9109998990380137, 0.910991378059046, 0.9109830516037853, 0.9109749122491176, 0.9109669528653702, 0.9109591666045709, 0.9109515468891936, 0.9109440874013562, 0.9109367820724581, 0.9109296250732324, 0.9109226108042063, 0.9109157338865437, 0.9109089891532594, 0.9109023716407844, 0.9108958765808746, 0.9108894993928467, 0.9108832356761204, 0.9108770812030681, 0.910871031912145, 0.9108650839013026, 0.9108592334216589, 0.9108534768714294, 0.9108478107900968, 0.9108422318528148, 0.9108367368650394, 0.9108313227573709, 0.9108259865806033, 0.9108207255009734, 0.9108155367955973, 0.9108104178480901, 0.9108053661443629, 0.9108003792685796, 0.9107954548992819, 0.910790590805671, 0.9107857848440268, 0.9107810349542778, 0.910776339156709, 0.9107716955487891, 0.9107671023021404, 0.9107625576596128, 0.9107580599324867, 0.9107536074977767, 0.9107491987956516, 0.91074 ...

# %%
ABC=[]
for i in range(M):
    abc=hypfunction(theta0,theta1,theta2,i)
    ABC.append(abc)
sns.scatterplot(X1,ABC)

# %%
sns.scatterplot(X2,Y)

# %%
sig=[]
for i in range(-10,10):
    sg=(1/(1+(math.exp(-i))))
    sig.append(sg)
sns.lineplot(np.arange(-10,10),sig)
